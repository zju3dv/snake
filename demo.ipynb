# %%
import sys
sys.argv.extend(['--cfg_file', 'configs/sbd_snake.yaml', 'demo_path', 'demo_images/2009_000871.jpg', 'ct_score', '0.3'])

from run import run_demo
run_demo()
# Out:
# load model: data/model/snake/sbd/199.pth
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.93it/s]
